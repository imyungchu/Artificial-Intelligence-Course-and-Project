# %% [markdown]
# # RDPG with OpenAI gym - PyTorch

# %% [markdown]
# ## Setup virtual display

# %%
# !apt-get update
# !apt-get install -y xvfb x11-utils
# !pip install pyvirtualdisplay==0.2.* \
             PyOpenGL==3.1.* \
             PyOpenGL-accelerate==3.1.*

## First we initialize a virtual display
import pyvirtualdisplay

_display = pyvirtualdisplay.Display(visible=False, size=(1400, 900)) #Use false with xvfb
_ = _display.start() 

# !echo $DISPLAY
# Out:
# Get:1 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Hit:2 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:4 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Hit:5 http://ppa.launchpad.net/cran/libgit2/ubuntu bionic InRelease
# Get:6 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic InRelease [15.9 kB]
# Get:7 http://archive.ubuntu.com/ubuntu bionic-backports InRelease [74.6 kB]
# Hit:8 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu bionic InRelease
# Get:9 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:10 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:11 http://security.ubuntu.com/ubuntu bionic-security/main amd64 Packages [2,461 kB]
# Get:12 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,452 kB]
# Get:13 http://security.ubuntu.com/ubuntu bionic-security/restricted amd64 Packages [691 kB]
# Get:14 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main Sources [1,821 kB]
# Get:15 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic/main amd64 Packages [934 kB]
# Ign:16 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Get:17 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [696 B]
# Hit:18 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:19 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:20 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 Packages [2,898 kB]
# Get:21 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 Packages [2,230 kB]
# Get:22 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu bionic/main amd64 Packages [45.3 kB]
# Get:23 http://archive.ubuntu.com/ubuntu bionic-backports/universe amd64 Packages [12.6 kB]
# Get:24 http://archive.ubuntu.com/ubuntu bionic-backports/main amd64 Packages [11.6 kB]
# Get:25 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ Packages [73.9 kB]
# Get:27 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Packages [833 kB]
# Fetched 13.8 MB in 4s (3,577 kB/s)
# Reading package lists... Done
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   libxxf86dga1 xserver-common
# Suggested packages:
#   mesa-utils
# Recommended packages:
#   xfonts-base
# The following NEW packages will be installed:
#   libxxf86dga1 x11-utils xvfb
# The following packages will be upgraded:
#   xserver-common
# 1 upgraded, 3 newly installed, 0 to remove and 81 not upgraded.
# Need to get 1,020 kB of archives.
# After this operation, 2,983 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/main amd64 libxxf86dga1 amd64 2:1.1.4-1 [13.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu bionic/main amd64 x11-utils amd64 7.7+3build1 [196 kB]
# Get:3 http://archive.ubuntu.com/ubuntu bionic-updates/main amd64 xserver-common all 2:1.19.6-1ubuntu4.10 [26.9 kB]
# Get:4 http://archive.ubuntu.com/ubuntu bionic-updates/universe amd64 xvfb amd64 2:1.19.6-1ubuntu4.10 [784 kB]
# Fetched 1,020 kB in 0s (10.3 MB/s)
# Selecting previously unselected package libxxf86dga1:amd64.
# (Reading database ... 155222 files and directories currently installed.)
# Preparing to unpack .../libxxf86dga1_2%3a1.1.4-1_amd64.deb ...
# Unpacking libxxf86dga1:amd64 (2:1.1.4-1) ...
# Selecting previously unselected package x11-utils.
# Preparing to unpack .../x11-utils_7.7+3build1_amd64.deb ...
# Unpacking x11-utils (7.7+3build1) ...
# Preparing to unpack .../xserver-common_2%3a1.19.6-1ubuntu4.10_all.deb ...
# Unpacking xserver-common (2:1.19.6-1ubuntu4.10) over (2:1.19.6-1ubuntu4.9) ...
# Selecting previously unselected package xvfb.
# Preparing to unpack .../xvfb_2%3a1.19.6-1ubuntu4.10_amd64.deb ...
# Unpacking xvfb (2:1.19.6-1ubuntu4.10) ...
# Setting up xserver-common (2:1.19.6-1ubuntu4.10) ...
# Setting up xvfb (2:1.19.6-1ubuntu4.10) ...
# Setting up libxxf86dga1:amd64 (2:1.1.4-1) ...
# Setting up x11-utils (7.7+3build1) ...
# Processing triggers for man-db (2.8.3-2ubuntu0.1) ...
# Processing triggers for libc-bin (2.27-3ubuntu1.3) ...
# /sbin/ldconfig.real: /usr/local/lib/python3.7/dist-packages/ideep4py/lib/libmkldnn.so.0 is not a symbolic link
#
# Collecting pyvirtualdisplay==0.2.*
#   Downloading PyVirtualDisplay-0.2.5-py2.py3-none-any.whl (13 kB)
# Requirement already satisfied: PyOpenGL==3.1.* in /usr/local/lib/python3.7/dist-packages (3.1.5)
# Collecting PyOpenGL-accelerate==3.1.*
#   Downloading PyOpenGL-accelerate-3.1.5.tar.gz (538 kB)
#      |████████████████████████████████| 538 kB 13.4 MB/s
# Collecting EasyProcess
#   Downloading EasyProcess-0.3-py2.py3-none-any.whl (7.9 kB)
# Building wheels for collected packages: PyOpenGL-accelerate
#   Building wheel for PyOpenGL-accelerate (setup.py) ... done
#   Created wheel for PyOpenGL-accelerate: filename=PyOpenGL_accelerate-3.1.5-cp37-cp37m-linux_x86_64.whl size=1599537 sha256=d212a2fcdf7e90190f80946204e71ff249b1220ae370607153926b8bbecd58b2
#   Stored in directory: /root/.cache/pip/wheels/1c/f5/6f/169afb3f2d476c5e807f8515b3c9bc9b819c3962316aa804eb
# Successfully built PyOpenGL-accelerate
# Installing collected packages: EasyProcess, pyvirtualdisplay, PyOpenGL-accelerate
# Successfully installed EasyProcess-0.3 PyOpenGL-accelerate-3.1.5 pyvirtualdisplay-0.2.5
# :1001

# %% [markdown]
# ## Import Libraries

# %%
import gym
import math
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from collections import namedtuple
from itertools import count
from PIL import Image
import cv2

import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import torchvision.transforms as T

from copy import deepcopy

# %matplotlib inline

# set up matplotlib
is_ipython = 'inline' in matplotlib.get_backend()
if is_ipython:
    from IPython import display

plt.ion()

# if gpu is to be used
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
# Out:
# cuda

# %% [markdown]
# ## Clone repo and set path

# %%
# %cd /content/
# !git clone https://github.com/ARG-NCTU/pytorch-rdpg.git
# Out:
# /content
# Cloning into 'pytorch-rdpg'...
# remote: Enumerating objects: 95, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 95 (delta 10), reused 10 (delta 10), pack-reused 80
# Unpacking objects: 100% (95/95), done.

# %%
import os
import sys

sys.path.append('/content/pytorch-rdpg')

from rdpg import RDPG
from model import Actor, Critic
from agent import Agent
from memory import EpisodicMemory
from torch.optim import Adam
from util import *
from normalized_env import *
from evaluator import *



# test for import packages
actor_net = Actor(300, 2)
critic_net = Critic(300, 2)

print(actor_net)
print(critic_net)
# Out:
# Actor(
#   (fc1): Linear(in_features=300, out_features=20, bias=True)
#   (fc2): Linear(in_features=20, out_features=50, bias=True)
#   (lstm): LSTMCell(50, 50)
#   (fc3): Linear(in_features=50, out_features=2, bias=True)
#   (relu): ReLU()
#   (tanh): Tanh()
# )
# Critic(
#   (fc1): Linear(in_features=300, out_features=20, bias=True)
#   (fc2): Linear(in_features=22, out_features=50, bias=True)
#   (fc3): Linear(in_features=50, out_features=1, bias=True)
#   (relu): ReLU()
# )

# %% [markdown]
# ## Setup OpenAI Gym Environment

# %% [markdown]
# The Box space represents an n-dimensional box, so valid observations will be an array of the numbers of state/action.
#
# We can also check the Box’s bounds (high and low).

# %%
env = gym.make('Pendulum-v0')
#env = NormalizedEnv(gym.make('Pendulum-v0'))

print(env.observation_space)
print(env.action_space)

nb_states = env.observation_space.shape[0]
nb_actions = env.action_space.shape[0]

print(nb_states)
print(env.observation_space.high)
print(env.observation_space.low)

print(nb_actions)
print(env.action_space.high)
print(env.action_space.low)
# Out:
# Box(-8.0, 8.0, (3,), float32)
# Box(-2.0, 2.0, (1,), float32)
# 3
# [1. 1. 8.]
# [-1. -1. -8.]
# 1
# [2.]
# [-2.]

# %% [markdown]
# ## Training
#
# Here we move the code in main.py to Colab

# %% [markdown]
# ### Prepare for Require parameters and RDPG Agent

# %%
class Args:
  mode = 'train'
  rate = 0.001   # learning rate
  prate = 0.0001 # policy net learning rate (only for DDPG)
  warmup = 10000  # time without training but only filling the replay memory
  discount = 0.99
  bsize = 64     # minibatch size
  rmsize = 6000000 # memory size 
  window_length = 1
  tau = 0.001      # moving average for target network
  ou_theta = 0.15  # noise theta
  ou_sigma = 0.2   # noise sigma
  ou_mu    = 0.0   # noise mu
  validate_episodes = 20
  trajectory_length = 5
  max_episode_length = 500
  validate_steps = 2000
  debug = 'debug'
  init_w = 0.003
  train_iter = 2000000 # default: 20000000
  epsilon = 50000 # linear decay of exploration policy
  seed = -1
  checkpoint = "checkpoints"
  checkpoint_path = "checkpoints_path"

args = Args()

evaluate = Evaluator(args.validate_episodes, 
            args.validate_steps, 
            args.max_episode_length)
agent = Agent(nb_states, nb_actions, args)
memory = EpisodicMemory(capacity=args.rmsize, max_episode_length=args.trajectory_length, window_length=args.window_length)
critic_optim  = Adam(agent.critic.parameters(), lr=args.rate)
actor_optim  = Adam(agent.actor.parameters(), lr=args.prate)

# %%
#  Tensorboard
from torch.utils.tensorboard import SummaryWriter
writer = SummaryWriter("runs/exp1")
print(writer.get_logdir())
# Out:
# runs/exp1

# %%
def update_policy():
        # Sample batch
        experiences = memory.sample(args.bsize)
        if len(experiences) == 0: # not enough samples
            return

        policy_loss_total = 0
        value_loss_total = 0
        for t in range(len(experiences) - 1): # iterate over episodes
            target_cx = Variable(torch.zeros(args.bsize, 50)).type(FLOAT)
            target_hx = Variable(torch.zeros(args.bsize, 50)).type(FLOAT)

            cx = Variable(torch.zeros(args.bsize, 50)).type(FLOAT)
            hx = Variable(torch.zeros(args.bsize, 50)).type(FLOAT)

            # we first get the data out of the sampled experience
            state0 = np.stack((trajectory.state0 for trajectory in experiences[t]))
            # action = np.expand_dims(np.stack((trajectory.action for trajectory in experiences[t])), axis=1)
            action = np.stack((trajectory.action for trajectory in experiences[t]))
            reward = np.expand_dims(np.stack((trajectory.reward for trajectory in experiences[t])), axis=1)
            # reward = np.stack((trajectory.reward for trajectory in experiences[t]))
            state1 = np.stack((trajectory.state0 for trajectory in experiences[t+1]))

            target_action, (target_hx, target_cx) = agent.actor_target(to_tensor(state1, volatile=True), (target_hx, target_cx))
            next_q_value = agent.critic_target([
                to_tensor(state1, volatile=True),
                target_action
            ])
            next_q_value.volatile=False

            target_q = to_tensor(reward) + args.discount*next_q_value

            # Critic update
            current_q = agent.critic([ to_tensor(state0), to_tensor(action) ])

            # value_loss = criterion(q_batch, target_q_batch)
            value_loss = F.smooth_l1_loss(current_q, target_q)
            value_loss /= len(experiences) # divide by trajectory length
            value_loss_total += value_loss

            # Actor update
            action, (hx, cx) = agent.actor(to_tensor(state0), (hx, cx))
            policy_loss = -agent.critic([
                to_tensor(state0),
                action
            ])
            policy_loss /= len(experiences) # divide by trajectory length
            policy_loss_total += policy_loss.mean()

            # update per trajectory
            agent.critic.zero_grad()
            agent.actor.zero_grad()
            
            value_loss.backward(retain_graph=True)
            
            policy_loss = policy_loss.mean()
            policy_loss.backward()
            
            critic_optim.step()
            actor_optim.step()

        # Target update
        soft_update(agent.actor_target, agent.actor, args.tau)
        soft_update(agent.critic_target, agent.critic, args.tau)

# %%
def train(num_iterations, checkpoint_path, debug):
        agent.is_training = True
        step = episode = episode_steps = trajectory_steps = 0
        episode_reward = 0.
        state0 = None
        while step < num_iterations:
            episode_steps = 0
            while episode_steps < args.max_episode_length:
                # reset if it is the start of episode
                if state0 is None:
                    state0 = deepcopy(env.reset())
                    agent.reset()

                # agent pick action ...
                if step <= args.warmup:
                    action = agent.random_action()
                else:
                    action = agent.select_action(state0)

                # env response with next_observation, reward, terminate_info
                state, reward, done, info = env.step(action)
                state = deepcopy(state)

                env.render()

                # agent observe and update policy
                memory.append(state0, action, reward, done)

                # update 
                step += 1
                episode_steps += 1
                trajectory_steps += 1
                episode_reward += reward
                state0 = deepcopy(state)

                if trajectory_steps >= args.trajectory_length:
                    agent.reset_lstm_hidden_state(done=False)
                    trajectory_steps = 0
                    if step > args.warmup:
                        update_policy()

                # [optional] save intermideate model
                if step % int(num_iterations/3) == 0:
                    agent.save_model(checkpoint_path)

                if done: # end of episode
                    if debug: prGreen('#{}: episode_reward:{} steps:{}'.format(episode,episode_reward,step))

                    writer.add_scalar('reward', episode_reward, step)

                    # reset
                    state0 = None
                    episode_reward = 0.
                    episode += 1
                    agent.reset_lstm_hidden_state(done=True)
                    break
            writer.close()
            # [optional] evaluate
            if evaluate is not None and args.validate_steps > 0 and step % args.validate_steps == 0:
                policy = lambda x: agent.select_action(x, decay_epsilon=False)
                validate_reward = evaluate(env, policy, debug=False, visualize=False)
                if debug: prYellow('[Evaluate] Step_{:07d}: mean_reward:{}'.format(step, validate_reward))

# %% [markdown]
# ### Training

# %%
train(args.train_iter, args.checkpoint, args.debug)
# Out:
#  #0: episode_reward:-751.1821816693467 steps:200
#  #1: episode_reward:-1069.0359171986572 steps:400
#  #2: episode_reward:-1356.8948132942107 steps:600
#  #3: episode_reward:-768.0366393723481 steps:800
#  #4: episode_reward:-754.1075630269876 steps:1000
#  #5: episode_reward:-1146.6488594084703 steps:1200
#  #6: episode_reward:-1509.1340118251692 steps:1400
#  #7: episode_reward:-1375.9579935184952 steps:1600
#  #8: episode_reward:-1170.2891982141132 steps:1800
#  #9: episode_reward:-946.7260754495705 steps:2000
#  [Evaluate] Step_0002000: mean_reward:-1134.301802490691
#  #10: episode_reward:-1577.5789908599033 steps:2200
#  #11: episode_reward:-762.3456996643465 steps:2400
#  #12: episode_reward:-980.4689121596575 steps:2600
#  #13: episode_reward:-1142.7666573218878 steps:2800
#  #14: episode_reward:-1590.9640896788364 steps:3000
#  #15: episode_reward:-1017.3652528542771 steps:3200
#  #16: episode_reward:-998.8568818302841 steps:3400
#  #17: episode_reward:-1070.4785519658367 steps:3600
#  #18: episode_reward:-1430.021553899462 steps:3800
#  #19: episode_reward:-1074.8690092770767 steps:4000
#  [Evaluate] Step_0004000: mean_reward:-1297.906757829721
#  #20: episode_reward:-1848.0079012632111 steps:4200
#  #21: episode_reward:-741.3165218071422 steps:4400
#  #22: episode_reward:-777.2238050437834 steps:4600
#  #23: episode_reward:-879.0385221127508 steps:4800
#  #24: episode_reward:-1773.7399436226794 steps:5000
#  #25: episode_reward:-1403.373295976104 steps:5200
#  #26: episode_reward:-1372.7837740158227 steps:5400
#  #27: episode_reward:-1548.5554575865367 steps:5600
#  #28: episode_reward:-1172.1176155217129 steps:5800
#  #29: episode_reward:-860.9590021007206 steps:6000
#  [Evaluate] Step_0006000: mean_reward:-1251.9608107832387
#  #30: episode_reward:-1535.5928074526917 steps:6200
#  #31: episode_reward:-715.6349705981137 steps:6400
#  #32: episode_reward:-896.5529966467419 steps:6600
#  #33: episode_reward:-893.5632588657265 steps:6800
#  #34: episode_reward:-1457.965850693396 steps:7000
#  #35: episode_reward:-1155.2868206208032 steps:7200
#  #36: episode_reward:-1500.632765452754 steps:7400
#  #37: episode_reward:-967.3514044056474 steps:7600
#  #38: episode_reward:-967.7012375270463 steps:7800
#  #39: episode_reward:-760.750635212005 steps:8000
#  [Evaluate] Step_0008000: mean_reward:-1306.0579161710598
#  #40: episode_reward:-1259.0634838455062 steps:8200
#  #41: episode_reward:-1571.715054280704 steps:8400
#  #42: episode_reward:-1061.987714619569 steps:8600
#  #43: episode_reward:-1482.0477605764763 steps:8800
#  #44: episode_reward:-1539.494236007533 steps:9000
#  #45: episode_reward:-1162.744795854542 steps:9200
#  #46: episode_reward:-1324.2942771380665 steps:9400
#  #47: episode_reward:-1155.0367362331444 steps:9600
#  #48: episode_reward:-837.0684769065647 steps:9800
#  #49: episode_reward:-751.9704234713817 steps:10000
#  [Evaluate] Step_0010000: mean_reward:-1273.1472894880735
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   """Entry point for launching an IPython kernel.
# /content/pytorch-rdpg/util.py:23: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#   torch.from_numpy(ndarray), volatile=volatile, requires_grad=requires_grad
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:29: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
#  #50: episode_reward:-1540.7055579532068 steps:10200
#  #51: episode_reward:-1157.2631457146163 steps:10400
#  #52: episode_reward:-1069.6598523322198 steps:10600
#  #53: episode_reward:-1729.7060968635906 steps:10800
#  #54: episode_reward:-1325.6697544339186 steps:11000
#  #55: episode_reward:-1335.4803897535414 steps:11200
#  #56: episode_reward:-1361.5915430645912 steps:11400
#  #57: episode_reward:-1510.2930495984328 steps:11600
#  #58: episode_reward:-1166.2455592268482 steps:11800
#  #59: episode_reward:-1364.2680219719175 steps:12000
#  [Evaluate] Step_0012000: mean_reward:-1390.202188356669
#  #60: episode_reward:-1644.4888980855815 steps:12200
#  #61: episode_reward:-861.4611418409073 steps:12400
#  #62: episode_reward:-1290.141663540618 steps:12600
#  #63: episode_reward:-1733.9154336641627 steps:12800
#  #64: episode_reward:-1177.0646692603389 steps:13000
#  #65: episode_reward:-1494.7802302759371 steps:13200
#  #66: episode_reward:-1334.539787595469 steps:13400
#  #67: episode_reward:-1513.8188807466624 steps:13600
#  #68: episode_reward:-1055.826403678351 steps:13800
#  #69: episode_reward:-1464.8224890554 steps:14000
#  [Evaluate] Step_0014000: mean_reward:-1281.2085749843288
#  #70: episode_reward:-1776.286683539459 steps:14200
#  #71: episode_reward:-1232.9299794875828 steps:14400
#  #72: episode_reward:-1349.89149582521 steps:14600
#  #73: episode_reward:-1368.4712038336736 steps:14800
#  #74: episode_reward:-1365.7870854829234 steps:15000
#  #75: episode_reward:-1238.12964150275 steps:15200
#  #76: episode_reward:-1510.129345616727 steps:15400
#  #77: episode_reward:-1068.3103353948316 steps:15600
#  #78: episode_reward:-1300.6312811169926 steps:15800
#  #79: episode_reward:-1373.2513296629736 steps:16000
#  [Evaluate] Step_0016000: mean_reward:-1284.0843948789611
#  #80: episode_reward:-1178.7791397567476 steps:16200
#  #81: episode_reward:-1174.4794239539244 steps:16400
#  #82: episode_reward:-1506.051460973533 steps:16600
#  #83: episode_reward:-932.2384165654868 steps:16800
#  #84: episode_reward:-1266.9446178417952 steps:17000
#  #85: episode_reward:-1056.6952179349782 steps:17200
#  #86: episode_reward:-1737.7245318872895 steps:17400
#  #87: episode_reward:-952.0639679645177 steps:17600
#  #88: episode_reward:-1141.4444420246998 steps:17800
#  #89: episode_reward:-1060.8792496847336 steps:18000
#  [Evaluate] Step_0018000: mean_reward:-1412.48136687791
#  #90: episode_reward:-1017.21896279582 steps:18200
#  #91: episode_reward:-962.1618291060558 steps:18400
#  #92: episode_reward:-1371.8561357805006 steps:18600
#  #93: episode_reward:-1064.1276904365818 steps:18800
#  #94: episode_reward:-1348.6718656400974 steps:19000
#  #95: episode_reward:-1368.266623630695 steps:19200
#  #96: episode_reward:-1051.8641144643445 steps:19400
#  #97: episode_reward:-954.3655248809991 steps:19600
#  #98: episode_reward:-1169.3833242381236 steps:19800
#  #99: episode_reward:-1693.5966369151022 steps:20000
#  [Evaluate] Step_0020000: mean_reward:-1304.8340236727702
#  #100: episode_reward:-1183.87556347626 steps:20200
#  #101: episode_reward:-1674.5017018596113 steps:20400
#  #102: episode_reward:-948.1519615948202 steps:20600
#  #103: episode_reward:-1358.3403484363384 steps:20800
#  #104: episode_reward:-1342.8985969749115 steps:21000
#  #105: episode_reward:-961.9502647409705 steps:21200
#  #106: episode_reward:-1168.7368178404315 steps:21400
#  #107: episode_reward:-1738.288628347846 steps:21600
#  #108: episode_reward:-1327.7531015389277 steps:21800
#  #109: episode_reward:-1312.9597719395242 steps:22000
#  [Evaluate] Step_0022000: mean_reward:-1442.659568596829
#  #110: episode_reward:-1342.4816268586292 steps:22200
#  #111: episode_reward:-1494.8061776390996 steps:22400
#  #112: episode_reward:-1449.0978978222436 steps:22600
#  #113: episode_reward:-1333.5083913510475 steps:22800
#  #114: episode_reward:-1365.0753544287952 steps:23000
#  #115: episode_reward:-1540.566176835563 steps:23200
#  #116: episode_reward:-1368.783599941607 steps:23400
#  #117: episode_reward:-1378.62517597542 steps:23600
#  #118: episode_reward:-964.1566389886611 steps:23800
#  #119: episode_reward:-948.2074976976385 steps:24000
#  [Evaluate] Step_0024000: mean_reward:-1311.986924109287
#  #120: episode_reward:-1362.3695271402441 steps:24200
#  #121: episode_reward:-1310.563748365608 steps:24400
#  #122: episode_reward:-1282.1292359497181 steps:24600
#  #123: episode_reward:-1352.2044967164497 steps:24800
#  #124: episode_reward:-1348.3630700858891 steps:25000
#  #125: episode_reward:-1699.3108070908534 steps:25200
#  #126: episode_reward:-1323.847136433865 steps:25400
#  #127: episode_reward:-1272.26702525112 steps:25600
#  #128: episode_reward:-953.5792580869844 steps:25800
#  #129: episode_reward:-1371.1701213654444 steps:26000
#  [Evaluate] Step_0026000: mean_reward:-1325.6461244014667
#  #130: episode_reward:-950.3390268770839 steps:26200
#  #131: episode_reward:-1694.2643527798234 steps:26400
#  #132: episode_reward:-1728.209276486927 steps:26600
#  #133: episode_reward:-1470.5316297452982 steps:26800
#  #134: episode_reward:-1005.1390255154741 steps:27000
#  #135: episode_reward:-1491.375923526043 steps:27200
#  #136: episode_reward:-1560.6648589001604 steps:27400
#  #137: episode_reward:-1724.2221487235086 steps:27600
#  #138: episode_reward:-1384.3474533391552 steps:27800
#  #139: episode_reward:-1357.3688504568952 steps:28000
#  [Evaluate] Step_0028000: mean_reward:-1276.512587362657
#  #140: episode_reward:-1382.6459926240386 steps:28200
#  #141: episode_reward:-1733.8429747485586 steps:28400
#  #142: episode_reward:-1526.415448951676 steps:28600
#  #143: episode_reward:-1340.321019769739 steps:28800
#  #144: episode_reward:-1348.1332053384729 steps:29000
#  #145: episode_reward:-1297.0793113607344 steps:29200
#  #146: episode_reward:-1314.9667368393252 steps:29400
#  #147: episode_reward:-1061.9097717190066 steps:29600
#  #148: episode_reward:-1295.2945222519154 steps:29800
#  #149: episode_reward:-1434.107393678649 steps:30000
#  [Evaluate] Step_0030000: mean_reward:-1403.104098325979
#  #150: episode_reward:-1342.3120690669043 steps:30200
#  #151: episode_reward:-1439.6428433114133 steps:30400
#  #152: episode_reward:-1345.2652094603652 steps:30600
#  #153: episode_reward:-1456.2197419825404 steps:30800
#  #154: episode_reward:-1184.6475893653596 steps:31000
#  #155: episode_reward:-1387.6020725415326 steps:31200
#  #156: episode_reward:-1263.773470594256 steps:31400
#  #157: episode_reward:-833.5472971070839 steps:31600
#  #158: episode_reward:-1498.449561384487 steps:31800
#  #159: episode_reward:-1544.5853893819844 steps:32000
#  [Evaluate] Step_0032000: mean_reward:-1327.4999402948108
#  #160: episode_reward:-1328.4233775015098 steps:32200
#  #161: episode_reward:-1124.1097844692063 steps:32400
#  #162: episode_reward:-1728.4429184152166 steps:32600
#  #163: episode_reward:-1274.6675614922676 steps:32800
#  #164: episode_reward:-1398.2480747423888 steps:33000
#  #165: episode_reward:-1353.3891040715193 steps:33200
#  #166: episode_reward:-1355.0582203636916 steps:33400
#  #167: episode_reward:-1311.810003372511 steps:33600
#  #168: episode_reward:-1338.2949018775341 steps:33800
#  #169: episode_reward:-1347.6885953181772 steps:34000
#  [Evaluate] Step_0034000: mean_reward:-1333.9217239756163
#  #170: episode_reward:-1295.9731774801467 steps:34200
#  #171: episode_reward:-1400.3874861681227 steps:34400
#  #172: episode_reward:-1163.8799559097354 steps:34600
#  #173: episode_reward:-1642.5190272132565 steps:34800
#  #174: episode_reward:-1407.1084734696644 steps:35000
#  #175: episode_reward:-1576.8722278376508 steps:35200
#  #176: episode_reward:-1336.1596589506867 steps:35400
#  #177: episode_reward:-1724.2137577961132 steps:35600
#  #178: episode_reward:-1045.9165332978382 steps:35800
#  #179: episode_reward:-1173.3990573648318 steps:36000
#  [Evaluate] Step_0036000: mean_reward:-1460.2882919494555
#  #180: episode_reward:-1279.1564686950371 steps:36200
#  #181: episode_reward:-1482.9975041933876 steps:36400
#  #182: episode_reward:-1336.9976430073 steps:36600
#  #183: episode_reward:-1366.039941882413 steps:36800
#  #184: episode_reward:-1483.162456372183 steps:37000
#  #185: episode_reward:-1316.1319393490328 steps:37200
#  #186: episode_reward:-1106.243985598946 steps:37400
#  #187: episode_reward:-1417.0966027514573 steps:37600
#  #188: episode_reward:-1352.1478470496663 steps:37800
#  #189: episode_reward:-1060.6063422455209 steps:38000
#  [Evaluate] Step_0038000: mean_reward:-1398.5133226173416
#  #190: episode_reward:-1471.781214300172 steps:38200
#  #191: episode_reward:-1302.877247643919 steps:38400
#  #192: episode_reward:-1155.9220820113692 steps:38600
#  #193: episode_reward:-1320.2347570963905 steps:38800
#  #194: episode_reward:-1599.049891936158 steps:39000
#  #195: episode_reward:-1423.986905878521 steps:39200
#  #196: episode_reward:-1343.7776560175369 steps:39400
#  #197: episode_reward:-1061.0104916694308 steps:39600
#  #198: episode_reward:-1735.1703617611497 steps:39800
#  #199: episode_reward:-1057.359287990174 steps:40000
#  [Evaluate] Step_0040000: mean_reward:-1381.4961091907232
#  #200: episode_reward:-1380.2040504538609 steps:40200
#  #201: episode_reward:-1359.536005225099 steps:40400
#  #202: episode_reward:-1346.9434655819093 steps:40600
#  #203: episode_reward:-1269.0525419874393 steps:40800
#  #204: episode_reward:-1361.506427714934 steps:41000
#  #205: episode_reward:-1749.7156143695838 steps:41200
#  #206: episode_reward:-1084.5619673445983 steps:41400
#  #207: episode_reward:-1677.9922235391136 steps:41600
#  #208: episode_reward:-1354.0358673569851 steps:41800
#  #209: episode_reward:-1370.1417868562462 steps:42000
#  [Evaluate] Step_0042000: mean_reward:-1290.8501293120314
#  #210: episode_reward:-1179.486151548849 steps:42200
#  #211: episode_reward:-1351.7650182755613 steps:42400
#  #212: episode_reward:-1373.5080086791243 steps:42600
#  #213: episode_reward:-1339.0532134001292 steps:42800
#  #214: episode_reward:-1342.2863454499463 steps:43000
#  #215: episode_reward:-1348.2527903418197 steps:43200
#  #216: episode_reward:-1600.4047579702694 steps:43400
#  #217: episode_reward:-1113.3209266078693 steps:43600
#  #218: episode_reward:-1090.8778343976862 steps:43800
#  #219: episode_reward:-1359.2956335823715 steps:44000
#  [Evaluate] Step_0044000: mean_reward:-1231.9037662751339
#  #220: episode_reward:-1364.6635525658062 steps:44200
#  #221: episode_reward:-1080.0158673587716 steps:44400
#  #222: episode_reward:-1370.2044689417448 steps:44600
#  #223: episode_reward:-1534.096527726942 steps:44800
#  #224: episode_reward:-1053.0390874012242 steps:45000
#  #225: episode_reward:-1196.4257259802168 steps:45200
#  #226: episode_reward:-790.8766347505133 steps:45400
#  #227: episode_reward:-1287.3916049378026 steps:45600
#  #228: episode_reward:-1325.3063477852454 steps:45800
#  #229: episode_reward:-1607.3158075460917 steps:46000
#  [Evaluate] Step_0046000: mean_reward:-1370.522411279659
#  #230: episode_reward:-1323.955533814285 steps:46200
#  #231: episode_reward:-1270.0603556964168 steps:46400
#  #232: episode_reward:-1163.2081632679253 steps:46600
#  #233: episode_reward:-1374.701881032881 steps:46800
#  #234: episode_reward:-1732.0957401333126 steps:47000
#  #235: episode_reward:-1416.2374805555721 steps:47200
#  #236: episode_reward:-1353.5062770385862 steps:47400
#  #237: episode_reward:-1270.1024410689129 steps:47600
#  #238: episode_reward:-1550.704028377253 steps:47800
#  #239: episode_reward:-1047.8362418706288 steps:48000
#  [Evaluate] Step_0048000: mean_reward:-1310.675141090247
#  #240: episode_reward:-1143.0788896229826 steps:48200
#  #241: episode_reward:-1352.5313978293848 steps:48400
#  #242: episode_reward:-1348.0667747347838 steps:48600
#  #243: episode_reward:-1193.3607032685704 steps:48800
#  #244: episode_reward:-949.2113225315043 steps:49000
#  #245: episode_reward:-1728.707506102604 steps:49200
#  #246: episode_reward:-1353.4795517590412 steps:49400
#  #247: episode_reward:-1139.5043595742336 steps:49600
#  #248: episode_reward:-1189.9042238421148 steps:49800
#  #249: episode_reward:-1446.7042525393083 steps:50000
#  [Evaluate] Step_0050000: mean_reward:-1346.0743808917962
#  #250: episode_reward:-1391.2357078610614 steps:50200
#  #251: episode_reward:-1271.542517808781 steps:50400
#  #252: episode_reward:-1531.9004342060114 steps:50600
#  #253: episode_reward:-1271.886226252439 steps:50800
#  #254: episode_reward:-1735.888139560109 steps:51000
#  #255: episode_reward:-1307.0363057199022 steps:51200
#  #256: episode_reward:-1339.5082292777915 steps:51400
#  #257: episode_reward:-1337.3294980744813 steps:51600
#  #258: episode_reward:-1545.4952255928984 steps:51800
#  #259: episode_reward:-1584.7692114757556 steps:52000
#  [Evaluate] Step_0052000: mean_reward:-1312.1841917613142
#  #260: episode_reward:-1384.6365678097357 steps:52200
#  #261: episode_reward:-1060.6067819123857 steps:52400
#  #262: episode_reward:-1341.8931882759293 steps:52600
#  #263: episode_reward:-1351.733240036606 steps:52800
#  #264: episode_reward:-1051.4106373217357 steps:53000
#  #265: episode_reward:-1239.4328260400523 steps:53200
#  #266: episode_reward:-1359.7101854955622 steps:53400
#  #267: episode_reward:-1514.1411017020175 steps:53600
#  #268: episode_reward:-1345.0388606825554 steps:53800
#  #269: episode_reward:-1738.108837076667 steps:54000
#  [Evaluate] Step_0054000: mean_reward:-1398.137677654586
#  #270: episode_reward:-1181.723352644758 steps:54200
#  #271: episode_reward:-1238.916595058703 steps:54400
#  #272: episode_reward:-1092.6211946867425 steps:54600
#  #273: episode_reward:-1730.1477883244902 steps:54800
#  #274: episode_reward:-1545.5067076773055 steps:55000
#  #275: episode_reward:-1252.4489478937635 steps:55200
#  #276: episode_reward:-1391.7996994939826 steps:55400
#  #277: episode_reward:-1347.1899933285424 steps:55600
#  #278: episode_reward:-1370.926843002823 steps:55800
#  #279: episode_reward:-1180.044781595224 steps:56000
#  [Evaluate] Step_0056000: mean_reward:-1298.666328765925
#  #280: episode_reward:-1349.3895281000848 steps:56200
#  #281: episode_reward:-1688.552089910817 steps:56400
#  #282: episode_reward:-1730.6475782060152 steps:56600
#  #283: episode_reward:-1741.5287197464716 steps:56800
#  #284: episode_reward:-1351.3909525811519 steps:57000
#  #285: episode_reward:-1303.7158814038062 steps:57200
#  #286: episode_reward:-1496.78778316674 steps:57400
#  #287: episode_reward:-1351.0316161103922 steps:57600
#  #288: episode_reward:-1553.4502462924404 steps:57800
#  #289: episode_reward:-1386.0798986572254 steps:58000
#  [Evaluate] Step_0058000: mean_reward:-1244.638543763313
#  #290: episode_reward:-1361.961951293614 steps:58200
#  #291: episode_reward:-1151.0559157420953 steps:58400
#  #292: episode_reward:-1307.4728913817487 steps:58600
#  #293: episode_reward:-1158.4253775424654 steps:58800
#  #294: episode_reward:-1372.9697049219742 steps:59000
#  #295: episode_reward:-913.8804884916068 steps:59200
#  #296: episode_reward:-1476.6506755285066 steps:59400
#  #297: episode_reward:-1019.2620279324055 steps:59600
#  #298: episode_reward:-1712.1004606396955 steps:59800
#  #299: episode_reward:-900.1888222204412 steps:60000
#  [Evaluate] Step_0060000: mean_reward:-1349.9518806577753
#  #300: episode_reward:-1370.9113644368865 steps:60200
#  #301: episode_reward:-1735.6464582120445 steps:60400
#  #302: episode_reward:-1373.4774136666872 steps:60600
#  #303: episode_reward:-1701.7355093966194 steps:60800
#  #304: episode_reward:-1335.5113515882017 steps:61000
#  #305: episode_reward:-1311.5788796186077 steps:61200
#  #306: episode_reward:-1351.089320223257 steps:61400
#  #307: episode_reward:-1373.7891156572903 steps:61600
#  #308: episode_reward:-1605.8550641214395 steps:61800
#  #309: episode_reward:-1363.383100740792 steps:62000
#  [Evaluate] Step_0062000: mean_reward:-1326.7934397449953
#  #310: episode_reward:-1025.6827298053677 steps:62200
#  #311: episode_reward:-1164.1052041553196 steps:62400
#  #312: episode_reward:-1376.5194599817535 steps:62600
#  #313: episode_reward:-1356.6667937351156 steps:62800
#  #314: episode_reward:-1368.5678304020466 steps:63000
#  #315: episode_reward:-1662.5549848904827 steps:63200
#  #316: episode_reward:-1168.2582873342242 steps:63400
#  #317: episode_reward:-1169.4662340702082 steps:63600
#  #318: episode_reward:-1322.7359866632326 steps:63800
#  #319: episode_reward:-1468.96735863727 steps:64000
#  [Evaluate] Step_0064000: mean_reward:-1355.0423984716958
#  #320: episode_reward:-1164.5210303989377 steps:64200
#  #321: episode_reward:-1172.2634698050383 steps:64400
#  #322: episode_reward:-1734.6927118376434 steps:64600
#  #323: episode_reward:-836.7149529314768 steps:64800
#  #324: episode_reward:-1073.6964518516045 steps:65000
#  #325: episode_reward:-1185.1855466191457 steps:65200
#  #326: episode_reward:-1362.8333839738002 steps:65400
#  #327: episode_reward:-1349.6302770019465 steps:65600
#  #328: episode_reward:-1672.0707650492684 steps:65800
#  #329: episode_reward:-1346.7278993250834 steps:66000
#  [Evaluate] Step_0066000: mean_reward:-1346.8345530968254
#  #330: episode_reward:-1666.5794609443433 steps:66200
#  #331: episode_reward:-1618.4219782380228 steps:66400
#  #332: episode_reward:-1321.6830395223599 steps:66600
#  #333: episode_reward:-1289.9363895487704 steps:66800
#  #334: episode_reward:-1382.688044637076 steps:67000
#  #335: episode_reward:-1364.0107969195822 steps:67200
#  #336: episode_reward:-1350.9665132435425 steps:67400
#  #337: episode_reward:-1353.0209332085717 steps:67600
#  #338: episode_reward:-1669.1155619486067 steps:67800
#  #339: episode_reward:-1103.0763217293154 steps:68000
#  [Evaluate] Step_0068000: mean_reward:-1286.3393814381407
#  #340: episode_reward:-1659.2350908803924 steps:68200
#  #341: episode_reward:-1160.0118196972394 steps:68400
#  #342: episode_reward:-1368.885999952453 steps:68600
#  #343: episode_reward:-1508.9974032471962 steps:68800
#  #344: episode_reward:-922.0293235301967 steps:69000
#  #345: episode_reward:-1375.5425148803838 steps:69200
#  #346: episode_reward:-1062.341800146062 steps:69400
#  #347: episode_reward:-1378.4035711851484 steps:69600
#  #348: episode_reward:-1324.0213630818523 steps:69800
#  #349: episode_reward:-1320.7703475309245 steps:70000
#  [Evaluate] Step_0070000: mean_reward:-1314.3490173246796
#  #350: episode_reward:-1628.4999164830826 steps:70200
#  #351: episode_reward:-1573.9404773174401 steps:70400
#  #352: episode_reward:-1709.3704189519979 steps:70600
#  #353: episode_reward:-1369.5743286890079 steps:70800
#  #354: episode_reward:-1431.5819484494255 steps:71000
#  #355: episode_reward:-1264.2049934627935 steps:71200
#  #356: episode_reward:-1366.8880952189268 steps:71400
#  #357: episode_reward:-1339.9560293742725 steps:71600
#  #358: episode_reward:-1352.8548577969327 steps:71800
#  #359: episode_reward:-1435.4063384950937 steps:72000
#  [Evaluate] Step_0072000: mean_reward:-1318.4360624128683
#  #360: episode_reward:-1585.9188789989357 steps:72200
#  #361: episode_reward:-1262.639043374747 steps:72400
#  #362: episode_reward:-1368.8864493980263 steps:72600
#  #363: episode_reward:-1064.0308491474523 steps:72800
#  #364: episode_reward:-1734.2142217272951 steps:73000
#  #365: episode_reward:-1342.2423382851216 steps:73200
#  #366: episode_reward:-1473.075788503363 steps:73400
#  #367: episode_reward:-1310.079334863541 steps:73600
#  #368: episode_reward:-1382.6133154812342 steps:73800
#  #369: episode_reward:-1343.5635769810942 steps:74000
#  [Evaluate] Step_0074000: mean_reward:-1361.1596949804998
#  #370: episode_reward:-937.3685232360198 steps:74200
#  #371: episode_reward:-1177.4267669861922 steps:74400
#  #372: episode_reward:-1347.4313564824913 steps:74600
#  #373: episode_reward:-1428.0785085006223 steps:74800
#  #374: episode_reward:-1273.719690506269 steps:75000
#  #375: episode_reward:-1365.8963074277774 steps:75200
#  #376: episode_reward:-1482.9191949506876 steps:75400
#  #377: episode_reward:-725.3616025166435 steps:75600
#  #378: episode_reward:-1354.0792634379657 steps:75800
#  #379: episode_reward:-1342.038426197103 steps:76000
#  [Evaluate] Step_0076000: mean_reward:-1347.8384970013062
#  #380: episode_reward:-1546.7423479016325 steps:76200
#  #381: episode_reward:-1436.5887880636699 steps:76400
#  #382: episode_reward:-1373.8810975357167 steps:76600
#  #383: episode_reward:-1196.4165487216355 steps:76800
#  #384: episode_reward:-1339.756301898534 steps:77000
#  #385: episode_reward:-1373.310748380726 steps:77200
#  #386: episode_reward:-1165.5597567746208 steps:77400
#  #387: episode_reward:-1651.8346377126122 steps:77600
#  #388: episode_reward:-1584.554735323578 steps:77800
#  #389: episode_reward:-1386.2497710737225 steps:78000
#  [Evaluate] Step_0078000: mean_reward:-1323.1750318978034
#  #390: episode_reward:-999.3850940161084 steps:78200
#  #391: episode_reward:-1577.9835398774317 steps:78400
#  #392: episode_reward:-1716.3964001915951 steps:78600
#  #393: episode_reward:-1366.9397567812223 steps:78800
#  #394: episode_reward:-853.6440351064285 steps:79000
#  #395: episode_reward:-1067.6246393775007 steps:79200
#  #396: episode_reward:-1207.1872196311779 steps:79400
#  #397: episode_reward:-1668.2751642816274 steps:79600
#  #398: episode_reward:-1365.2203919968013 steps:79800
#  #399: episode_reward:-1408.6713354893889 steps:80000
#  [Evaluate] Step_0080000: mean_reward:-1386.2328768788796
#  #400: episode_reward:-1480.8323293993562 steps:80200
#  #401: episode_reward:-1347.2203971646968 steps:80400
#  #402: episode_reward:-1352.1971081341812 steps:80600
#  #403: episode_reward:-1029.1950794589711 steps:80800
#  #404: episode_reward:-1688.416607893412 steps:81000
#  #405: episode_reward:-1408.4551967391026 steps:81200
#  #406: episode_reward:-1705.7319180342945 steps:81400
#  #407: episode_reward:-925.1051040451607 steps:81600
#  #408: episode_reward:-1358.1847398489813 steps:81800
#  #409: episode_reward:-1164.3283802978347 steps:82000
#  [Evaluate] Step_0082000: mean_reward:-1391.0740360369148
#  #410: episode_reward:-1736.899297063254 steps:82200
#  #411: episode_reward:-1515.8290865772383 steps:82400
#  #412: episode_reward:-1103.8626081611592 steps:82600
#  #413: episode_reward:-1356.5682093835974 steps:82800
#  #414: episode_reward:-1373.6464256701945 steps:83000
#  #415: episode_reward:-1333.6968876232927 steps:83200
#  #416: episode_reward:-1350.9660907623627 steps:83400
#  #417: episode_reward:-1491.2180037709677 steps:83600
#  #418: episode_reward:-1518.3161950391238 steps:83800
#  #419: episode_reward:-1598.5324584242803 steps:84000
#  [Evaluate] Step_0084000: mean_reward:-1390.0337604485533
#  #420: episode_reward:-1059.132799547143 steps:84200
#  #421: episode_reward:-1705.1352654235318 steps:84400
#  #422: episode_reward:-968.723375912689 steps:84600
#  #423: episode_reward:-1008.4503140863783 steps:84800
#  #424: episode_reward:-1353.6996815636942 steps:85000
#  #425: episode_reward:-1246.3074713933527 steps:85200
#  #426: episode_reward:-948.8136666602268 steps:85400
#  #427: episode_reward:-950.1447215403782 steps:85600
#  #428: episode_reward:-1258.3980257916076 steps:85800
#  #429: episode_reward:-1218.9136516376536 steps:86000
#  [Evaluate] Step_0086000: mean_reward:-1368.287827865223
#  #430: episode_reward:-1680.9231868179925 steps:86200
#  #431: episode_reward:-1350.7031649984485 steps:86400
#  #432: episode_reward:-1053.127509647808 steps:86600
#  #433: episode_reward:-1360.666686571793 steps:86800
#  #434: episode_reward:-1713.2771403987463 steps:87000
#  #435: episode_reward:-1268.5166874477602 steps:87200
#  #436: episode_reward:-964.4414899985562 steps:87400
#  #437: episode_reward:-1196.7755215691327 steps:87600
#  #438: episode_reward:-1240.8731592297077 steps:87800
#  #439: episode_reward:-1044.2392303683132 steps:88000
#  [Evaluate] Step_0088000: mean_reward:-1357.0087317844414
#  #440: episode_reward:-1098.8416521650865 steps:88200
#  #441: episode_reward:-1597.000457355128 steps:88400
#  #442: episode_reward:-1174.3206792337878 steps:88600
#  #443: episode_reward:-1683.0333089553164 steps:88800
#  #444: episode_reward:-1380.0038517505036 steps:89000
#  #445: episode_reward:-1350.1569705873026 steps:89200
#  #446: episode_reward:-1304.5119298166153 steps:89400
#  #447: episode_reward:-717.2964207992756 steps:89600
#  #448: episode_reward:-1237.1274455964822 steps:89800
#  #449: episode_reward:-1346.1000895344591 steps:90000
#  [Evaluate] Step_0090000: mean_reward:-1437.7281948225498
#  #450: episode_reward:-1165.9317815690215 steps:90200
#  #451: episode_reward:-1706.6998402100294 steps:90400
#  #452: episode_reward:-1347.2321464247811 steps:90600
#  #453: episode_reward:-1162.4505301684258 steps:90800
#  #454: episode_reward:-1370.2402676351935 steps:91000
#  #455: episode_reward:-1596.6891628407366 steps:91200
#  #456: episode_reward:-1155.9065967640781 steps:91400
#  #457: episode_reward:-1470.4191222235763 steps:91600
#  #458: episode_reward:-1469.4535127266417 steps:91800
#  #459: episode_reward:-1357.0734128041258 steps:92000
#  [Evaluate] Step_0092000: mean_reward:-1399.3258485154195
#  #460: episode_reward:-1351.2475287661234 steps:92200
#  #461: episode_reward:-1298.4621807968358 steps:92400
#  #462: episode_reward:-1614.6414315484062 steps:92600
#  #463: episode_reward:-1068.8126817350849 steps:92800
#  #464: episode_reward:-1320.9571230298411 steps:93000
#  #465: episode_reward:-1373.808244859662 steps:93200
#  #466: episode_reward:-1060.354593245718 steps:93400
#  #467: episode_reward:-1500.7714900757474 steps:93600
#  #468: episode_reward:-1735.0525681364059 steps:93800
#  #469: episode_reward:-1358.2948069336035 steps:94000
#  [Evaluate] Step_0094000: mean_reward:-1269.89146354852
#  #470: episode_reward:-1372.9076808329594 steps:94200
#  #471: episode_reward:-1287.6329862609548 steps:94400
#  #472: episode_reward:-1312.062989760862 steps:94600
#  #473: episode_reward:-949.3389157440539 steps:94800
#  #474: episode_reward:-1172.174118880851 steps:95000
#  #475: episode_reward:-1634.819767817434 steps:95200
#  #476: episode_reward:-1322.0366775453563 steps:95400
#  #477: episode_reward:-1315.6183954885819 steps:95600
#  #478: episode_reward:-948.6157764404352 steps:95800
#  #479: episode_reward:-1444.84965646347 steps:96000
#  [Evaluate] Step_0096000: mean_reward:-1228.9939176648338
#  #480: episode_reward:-1361.8097064077542 steps:96200
#  #481: episode_reward:-1680.2384155426564 steps:96400
#  #482: episode_reward:-1355.3687061875128 steps:96600
#  #483: episode_reward:-1248.0414976481281 steps:96800
#  #484: episode_reward:-725.2378761432523 steps:97000
#  #485: episode_reward:-1736.3572224777083 steps:97200
#  #486: episode_reward:-1615.2492704408908 steps:97400
#  #487: episode_reward:-1154.2974472242213 steps:97600
#  #488: episode_reward:-1362.9747692640979 steps:97800
#  #489: episode_reward:-889.7809665852935 steps:98000
#  [Evaluate] Step_0098000: mean_reward:-1350.2729037858476
#  #490: episode_reward:-1369.6314326747508 steps:98200
#  #491: episode_reward:-1528.323932064173 steps:98400
#  #492: episode_reward:-1394.3175758104348 steps:98600
#  #493: episode_reward:-833.0725077109731 steps:98800
#  #494: episode_reward:-1557.4370253509949 steps:99000
#  #495: episode_reward:-1399.2153138044507 steps:99200
#  #496: episode_reward:-1728.0438694093912 steps:99400
#  #497: episode_reward:-1372.2750280031023 steps:99600
#  #498: episode_reward:-946.7166547447788 steps:99800
#  #499: episode_reward:-1368.9546290729238 steps:100000
#  [Evaluate] Step_0100000: mean_reward:-1328.7751698776017
#  #500: episode_reward:-1383.3386106309433 steps:100200
#  #501: episode_reward:-1376.160174764366 steps:100400
#  #502: episode_reward:-1361.022253388289 steps:100600
#  #503: episode_reward:-1323.9104071979657 steps:100800
#  #504: episode_reward:-1389.6475268411355 steps:101000
#  #505: episode_reward:-1711.1839667958056 steps:101200
#  #506: episode_reward:-1340.920333533197 steps:101400
#  #507: episode_reward:-1347.1975314381496 steps:101600
#  #508: episode_reward:-1148.7647089455807 steps:101800
#  #509: episode_reward:-1510.5671837749585 steps:102000
#  [Evaluate] Step_0102000: mean_reward:-1346.9310857832475
#  #510: episode_reward:-1490.8333514434469 steps:102200
#  #511: episode_reward:-1372.6305916994702 steps:102400
#  #512: episode_reward:-1196.1671469652974 steps:102600
#  #513: episode_reward:-1358.1186083677721 steps:102800
#  #514: episode_reward:-1589.0809413017544 steps:103000
#  #515: episode_reward:-947.4172035658133 steps:103200
#  #516: episode_reward:-1301.7367636780548 steps:103400
#  #517: episode_reward:-1371.9920106279128 steps:103600
#  #518: episode_reward:-944.7218772088139 steps:103800
#  #519: episode_reward:-1513.5280605472042 steps:104000
#  [Evaluate] Step_0104000: mean_reward:-1276.4389304869442
#  #520: episode_reward:-1170.7275583460291 steps:104200
#  #521: episode_reward:-1347.3994996334761 steps:104400
#  #522: episode_reward:-949.3401496839984 steps:104600
#  #523: episode_reward:-1352.5373565745817 steps:104800
#  #524: episode_reward:-1351.0721653914134 steps:105000
#  #525: episode_reward:-1343.7145837266398 steps:105200
#  #526: episode_reward:-1341.1656970256638 steps:105400
#  #527: episode_reward:-1348.161373993341 steps:105600
#  #528: episode_reward:-1353.7485609580303 steps:105800
#  #529: episode_reward:-1715.809508397971 steps:106000
#  [Evaluate] Step_0106000: mean_reward:-1269.2885076048374
#  #530: episode_reward:-1341.8374729927914 steps:106200
#  #531: episode_reward:-1317.7075749826274 steps:106400
#  #532: episode_reward:-968.6531980007663 steps:106600
#  #533: episode_reward:-1400.2982780703496 steps:106800
#  #534: episode_reward:-1562.9781109659018 steps:107000
#  #535: episode_reward:-1178.6346644986945 steps:107200
#  #536: episode_reward:-1058.4475988945896 steps:107400
#  #537: episode_reward:-1301.03327269372 steps:107600
#  #538: episode_reward:-1119.3826401819772 steps:107800
#  #539: episode_reward:-1357.2696044305028 steps:108000
#  [Evaluate] Step_0108000: mean_reward:-1385.3559327024466
#  #540: episode_reward:-1637.831825845303 steps:108200
#  #541: episode_reward:-1359.5714681779596 steps:108400
#  #542: episode_reward:-1308.8778936497667 steps:108600
#  #543: episode_reward:-1341.3254710566011 steps:108800
#  #544: episode_reward:-1085.2607195775765 steps:109000
#  #545: episode_reward:-1375.1525387369788 steps:109200
#  #546: episode_reward:-1485.4480060692038 steps:109400
#  #547: episode_reward:-1370.0548793610292 steps:109600
#  #548: episode_reward:-1434.5237251327037 steps:109800
#  #549: episode_reward:-1365.231228610764 steps:110000
#  [Evaluate] Step_0110000: mean_reward:-1327.6445605192064
#  #550: episode_reward:-1338.669668017624 steps:110200
#  #551: episode_reward:-1383.676279740527 steps:110400
#  #552: episode_reward:-1539.5570471964356 steps:110600
#  #553: episode_reward:-1352.8699400388307 steps:110800
#  #554: episode_reward:-1419.7097005764567 steps:111000
#  #555: episode_reward:-1170.4792721766046 steps:111200
#  #556: episode_reward:-1079.542160830367 steps:111400
#  #557: episode_reward:-1184.836162793133 steps:111600
#  #558: episode_reward:-1349.569314309502 steps:111800
#  #559: episode_reward:-1730.2300018512474 steps:112000
#  [Evaluate] Step_0112000: mean_reward:-1402.7993663504499
#  #560: episode_reward:-938.5022306042141 steps:112200
#  #561: episode_reward:-1182.7378520873413 steps:112400
#  #562: episode_reward:-1732.844561971931 steps:112600
#  #563: episode_reward:-1656.52401875304 steps:112800
#  #564: episode_reward:-1143.6550445785374 steps:113000
#  #565: episode_reward:-717.245149202971 steps:113200
#  #566: episode_reward:-1395.339669187906 steps:113400
#  #567: episode_reward:-1357.3305431282754 steps:113600
#  #568: episode_reward:-1300.4803118818354 steps:113800
#  #569: episode_reward:-1382.0055919026797 steps:114000
#  [Evaluate] Step_0114000: mean_reward:-1223.476079384647
#  #570: episode_reward:-1727.4102684100926 steps:114200
#  #571: episode_reward:-1202.6728503595232 steps:114400
#  #572: episode_reward:-1360.402056185416 steps:114600
#  #573: episode_reward:-1200.8872652064924 steps:114800
#  #574: episode_reward:-1737.3877661370439 steps:115000
#  #575: episode_reward:-1734.1536385765705 steps:115200
#  #576: episode_reward:-1696.0285293558945 steps:115400
#  #577: episode_reward:-1403.6843022078751 steps:115600
#  #578: episode_reward:-1174.7019412044035 steps:115800
#  #579: episode_reward:-1478.163446687381 steps:116000
#  [Evaluate] Step_0116000: mean_reward:-1309.0522303919488
#  #580: episode_reward:-1255.1364701041837 steps:116200
#  #581: episode_reward:-850.1379750594205 steps:116400
#  #582: episode_reward:-1699.8751425207572 steps:116600
#  #583: episode_reward:-1396.6404227416365 steps:116800
#  #584: episode_reward:-1304.7451424406738 steps:117000
#  #585: episode_reward:-1492.4521193132828 steps:117200
#  #586: episode_reward:-1668.9565706253532 steps:117400
#  #587: episode_reward:-1460.8458482989893 steps:117600
#  #588: episode_reward:-1342.8434684402328 steps:117800
#  #589: episode_reward:-1261.5870770728397 steps:118000
#  [Evaluate] Step_0118000: mean_reward:-1449.9647214395823
#  #590: episode_reward:-1351.6717581723615 steps:118200
#  #591: episode_reward:-1064.1419637701745 steps:118400
#  #592: episode_reward:-1330.6784925520124 steps:118600
#  #593: episode_reward:-1661.7080074530763 steps:118800
#  #594: episode_reward:-1544.2355527342115 steps:119000
#  #595: episode_reward:-1136.5807228046858 steps:119200
#  #596: episode_reward:-1256.1199329803271 steps:119400
#  #597: episode_reward:-1245.6036301922188 steps:119600
#  #598: episode_reward:-1221.8158020258834 steps:119800
#  #599: episode_reward:-1066.6299531183067 steps:120000
#  [Evaluate] Step_0120000: mean_reward:-1193.598448407404
#  #600: episode_reward:-1189.3031192381645 steps:120200
#  #601: episode_reward:-915.8362432609099 steps:120400
#  #602: episode_reward:-1235.5272627044428 steps:120600
#  #603: episode_reward:-1264.0012218425372 steps:120800
#  #604: episode_reward:-1355.7144665528613 steps:121000
#  #605: episode_reward:-1341.3720233688196 steps:121200
#  #606: episode_reward:-1734.514311402562 steps:121400
#  #607: episode_reward:-815.399601105844 steps:121600
#  #608: episode_reward:-1321.6789030981104 steps:121800
#  #609: episode_reward:-1290.3753779499286 steps:122000
#  [Evaluate] Step_0122000: mean_reward:-1297.9510410071166
#  #610: episode_reward:-1384.8003049956644 steps:122200
#  #611: episode_reward:-1659.5854221181899 steps:122400
#  #612: episode_reward:-1145.836119546095 steps:122600
#  #613: episode_reward:-1344.3311486384196 steps:122800
#  #614: episode_reward:-1282.749850736386 steps:123000
#  #615: episode_reward:-1273.9171562047761 steps:123200
#  #616: episode_reward:-1576.7097152900944 steps:123400
#  #617: episode_reward:-1331.7092630576553 steps:123600
#  #618: episode_reward:-1297.8442568350588 steps:123800
#  #619: episode_reward:-1036.350482416927 steps:124000
#  [Evaluate] Step_0124000: mean_reward:-1391.912008143899
#  #620: episode_reward:-1344.924725593936 steps:124200
#  #621: episode_reward:-1343.7588845754285 steps:124400
#  #622: episode_reward:-1732.4237944835902 steps:124600
#  #623: episode_reward:-1381.6622584787995 steps:124800
#  #624: episode_reward:-1286.7643004817292 steps:125000
#  #625: episode_reward:-810.1142100969064 steps:125200
#  #626: episode_reward:-1608.2480241371852 steps:125400
#  #627: episode_reward:-1556.3615245781937 steps:125600
#  #628: episode_reward:-1366.972064658364 steps:125800
#  #629: episode_reward:-1720.4728019256818 steps:126000
#  [Evaluate] Step_0126000: mean_reward:-1251.8995830275828
#  #630: episode_reward:-1143.9747994570641 steps:126200
#  #631: episode_reward:-1356.7865072987763 steps:126400
#  #632: episode_reward:-1372.0977985103248 steps:126600
#  #633: episode_reward:-1350.3071965564734 steps:126800
#  #634: episode_reward:-1005.3935917036229 steps:127000
#  #635: episode_reward:-1363.0225297561196 steps:127200
#  #636: episode_reward:-1498.246767691164 steps:127400
#  #637: episode_reward:-1333.7846741714957 steps:127600
#  #638: episode_reward:-1367.99709229875 steps:127800
#  #639: episode_reward:-1476.0239434081036 steps:128000
#  [Evaluate] Step_0128000: mean_reward:-1291.3442873938209
#  #640: episode_reward:-1347.0992100677877 steps:128200
#  #641: episode_reward:-1025.4382102998406 steps:128400
#  #642: episode_reward:-1042.9280502190034 steps:128600
#  #643: episode_reward:-1196.9049197250058 steps:128800
#  #644: episode_reward:-1372.3080867379397 steps:129000
#  #645: episode_reward:-1638.69119657006 steps:129200
#  #646: episode_reward:-1073.7619859606564 steps:129400
#  #647: episode_reward:-1586.4574379056091 steps:129600
#  #648: episode_reward:-1383.2452622992225 steps:129800
#  #649: episode_reward:-1733.7659099621133 steps:130000
#  [Evaluate] Step_0130000: mean_reward:-1316.1837355186967
#  #650: episode_reward:-1335.0812117438963 steps:130200
#  #651: episode_reward:-1341.1114128598742 steps:130400
#  #652: episode_reward:-1541.4716475419455 steps:130600
#  #653: episode_reward:-1185.3984852325889 steps:130800
#  #654: episode_reward:-969.4961595689371 steps:131000
#  #655: episode_reward:-1112.0055051616139 steps:131200
#  #656: episode_reward:-1339.4573203486207 steps:131400
#  #657: episode_reward:-1158.003337198044 steps:131600
#  #658: episode_reward:-718.1230595865585 steps:131800
#  #659: episode_reward:-1295.0704929938286 steps:132000
#  [Evaluate] Step_0132000: mean_reward:-1370.1340711012183
#  #660: episode_reward:-974.0370875749936 steps:132200
#  #661: episode_reward:-1119.6401634707381 steps:132400
#  #662: episode_reward:-1281.3896739633578 steps:132600
#  #663: episode_reward:-1167.1481973533541 steps:132800
#  #664: episode_reward:-1559.6008111104072 steps:133000
#  #665: episode_reward:-1292.5231358320846 steps:133200
#  #666: episode_reward:-1360.40968205963 steps:133400
#  #667: episode_reward:-1348.2220437112505 steps:133600
#  #668: episode_reward:-1730.311905146471 steps:133800
#  #669: episode_reward:-1023.0174291659846 steps:134000
#  [Evaluate] Step_0134000: mean_reward:-1371.852345330853
#  #670: episode_reward:-1098.4595344043935 steps:134200
#  #671: episode_reward:-1357.9008433330569 steps:134400
#  #672: episode_reward:-1622.4673871361642 steps:134600
#  #673: episode_reward:-1731.368417314869 steps:134800
#  #674: episode_reward:-1338.0276444507654 steps:135000
#  #675: episode_reward:-1377.7792095988923 steps:135200
#  #676: episode_reward:-836.3105626224312 steps:135400
#  #677: episode_reward:-948.8754594345799 steps:135600
#  #678: episode_reward:-1393.796223298975 steps:135800
#  #679: episode_reward:-1731.8326411141873 steps:136000
#  [Evaluate] Step_0136000: mean_reward:-1259.0073956979797
#  #680: episode_reward:-1554.118428031327 steps:136200
#  #681: episode_reward:-1389.0544603117007 steps:136400
#  #682: episode_reward:-1711.6000194638157 steps:136600
#  #683: episode_reward:-1562.2815713279517 steps:136800
#  #684: episode_reward:-1739.0446965797944 steps:137000
#  #685: episode_reward:-1058.8403234856235 steps:137200
#  #686: episode_reward:-1732.7981191188212 steps:137400
#  #687: episode_reward:-998.5295743108353 steps:137600
#  #688: episode_reward:-1568.2398544254293 steps:137800
#  #689: episode_reward:-1475.0516908526736 steps:138000
#  [Evaluate] Step_0138000: mean_reward:-1344.7315328583097
#  #690: episode_reward:-1167.6902890696833 steps:138200
#  #691: episode_reward:-1337.2731276351228 steps:138400
#  #692: episode_reward:-1338.1321806789038 steps:138600
#  #693: episode_reward:-1380.5405736818318 steps:138800
#  #694: episode_reward:-1365.3065832265484 steps:139000
#  #695: episode_reward:-1534.200479217929 steps:139200
#  #696: episode_reward:-945.0110960100585 steps:139400
#  #697: episode_reward:-1296.314768318661 steps:139600
#  #698: episode_reward:-1171.3412679008784 steps:139800
#  #699: episode_reward:-1175.3467334717216 steps:140000
#  [Evaluate] Step_0140000: mean_reward:-1326.0691502459356
#  #700: episode_reward:-1627.7284076275039 steps:140200
#  #701: episode_reward:-1002.3690380666928 steps:140400
#  #702: episode_reward:-1168.0837027896825 steps:140600
#  #703: episode_reward:-1602.0021964589455 steps:140800
#  #704: episode_reward:-1386.6925438239327 steps:141000
#  #705: episode_reward:-977.2910692147767 steps:141200
#  #706: episode_reward:-1364.8571021322223 steps:141400
#  #707: episode_reward:-1367.343732498981 steps:141600
#  #708: episode_reward:-1382.463148297329 steps:141800
#  #709: episode_reward:-1733.8536162643773 steps:142000
#  [Evaluate] Step_0142000: mean_reward:-1394.6879690559385
#  #710: episode_reward:-1732.9996104710658 steps:142200
#  #711: episode_reward:-1384.7152571796898 steps:142400
#  #712: episode_reward:-1198.0299846175287 steps:142600
#  #713: episode_reward:-1729.1488981464838 steps:142800
#  #714: episode_reward:-1163.517506158672 steps:143000
#  #715: episode_reward:-1064.065936210915 steps:143200
#  #716: episode_reward:-953.3016773159991 steps:143400
#  #717: episode_reward:-1321.610640082831 steps:143600
#  #718: episode_reward:-1470.8489618338879 steps:143800
#  #719: episode_reward:-1362.6657477554816 steps:144000
#  [Evaluate] Step_0144000: mean_reward:-1334.1721839612817
#  #720: episode_reward:-1670.5882647150697 steps:144200
#  #721: episode_reward:-1312.3773777042866 steps:144400
#  #722: episode_reward:-1031.4864234966105 steps:144600
#  #723: episode_reward:-1358.5289514440167 steps:144800
#  #724: episode_reward:-926.5720872130582 steps:145000
#  #725: episode_reward:-948.144027082984 steps:145200
#  #726: episode_reward:-1366.1148121812585 steps:145400
#  #727: episode_reward:-1625.0168206195115 steps:145600
#  #728: episode_reward:-1383.2095645077097 steps:145800
#  #729: episode_reward:-1463.3393686437307 steps:146000
#  [Evaluate] Step_0146000: mean_reward:-1304.183143808303
#  #730: episode_reward:-1389.6334287050702 steps:146200
#  #731: episode_reward:-1352.3597143174661 steps:146400
#  #732: episode_reward:-1219.6308335003407 steps:146600
#  #733: episode_reward:-1069.640573949053 steps:146800
#  #734: episode_reward:-950.1978744621581 steps:147000
#  #735: episode_reward:-1391.2605966576075 steps:147200
#  #736: episode_reward:-1359.5349126456374 steps:147400
#  #737: episode_reward:-1359.5708744995818 steps:147600
#  #738: episode_reward:-780.3574970810677 steps:147800
#  #739: episode_reward:-1237.2579923178844 steps:148000
#  [Evaluate] Step_0148000: mean_reward:-1356.0615222002666
#  #740: episode_reward:-1374.8380806753817 steps:148200
#  #741: episode_reward:-1357.96576681117 steps:148400
#  #742: episode_reward:-1423.0556377318464 steps:148600
#  #743: episode_reward:-1273.3191176674006 steps:148800
#  #744: episode_reward:-1474.4212016354288 steps:149000
#  #745: episode_reward:-1347.6267579029059 steps:149200
#  #746: episode_reward:-1413.3732819441227 steps:149400
#  #747: episode_reward:-1533.7348195841535 steps:149600
#  #748: episode_reward:-1595.1185509287589 steps:149800
#  #749: episode_reward:-1376.9278911899692 steps:150000
#  [Evaluate] Step_0150000: mean_reward:-1299.8407721573024
#  #750: episode_reward:-1732.5139514836844 steps:150200
#  #751: episode_reward:-1373.2025679852804 steps:150400
#  #752: episode_reward:-1361.7280612927539 steps:150600
#  #753: episode_reward:-1152.092011314344 steps:150800
#  #754: episode_reward:-717.484040095876 steps:151000
#  #755: episode_reward:-1330.191756033169 steps:151200
#  #756: episode_reward:-1339.2287770894516 steps:151400
#  #757: episode_reward:-1362.3949324393857 steps:151600
#  #758: episode_reward:-818.3825672283609 steps:151800
#  #759: episode_reward:-1372.7382916608747 steps:152000
#  [Evaluate] Step_0152000: mean_reward:-1285.7383224565774
#  #760: episode_reward:-1280.0292175104616 steps:152200
#  #761: episode_reward:-1336.4201506518514 steps:152400
#  #762: episode_reward:-1352.7097027539962 steps:152600
#  #763: episode_reward:-1548.5521279802317 steps:152800
#  #764: episode_reward:-1222.1709603119418 steps:153000
#  #765: episode_reward:-1381.0136088364206 steps:153200
#  #766: episode_reward:-950.2021331356076 steps:153400
#  #767: episode_reward:-1055.7304496363881 steps:153600
#  #768: episode_reward:-1387.6417613346875 steps:153800
#  #769: episode_reward:-1678.4821243858553 steps:154000
#  [Evaluate] Step_0154000: mean_reward:-1310.9163079872528
#  #770: episode_reward:-1530.3555201602678 steps:154200
#  #771: episode_reward:-1072.0940817990804 steps:154400
#  #772: episode_reward:-1360.566581604823 steps:154600
#  #773: episode_reward:-1332.1870403134171 steps:154800
#  #774: episode_reward:-1734.9020812773554 steps:155000
#  #775: episode_reward:-1354.3887691309897 steps:155200
#  #776: episode_reward:-800.5926475155408 steps:155400
#  #777: episode_reward:-1295.567466724505 steps:155600
#  #778: episode_reward:-1178.3916683867806 steps:155800
#  #779: episode_reward:-1138.123976162292 steps:156000
#  [Evaluate] Step_0156000: mean_reward:-1296.383876213648
#  #780: episode_reward:-1084.069737777824 steps:156200
#  #781: episode_reward:-1171.6107149228449 steps:156400
#  #782: episode_reward:-1159.208320572846 steps:156600
#  #783: episode_reward:-1734.017387136493 steps:156800
#  #784: episode_reward:-909.9187046840999 steps:157000
#  #785: episode_reward:-1313.6495529995263 steps:157200
#  #786: episode_reward:-1738.7675457729129 steps:157400
#  #787: episode_reward:-1733.0450431011636 steps:157600
#  #788: episode_reward:-1440.4494702150487 steps:157800
#  #789: episode_reward:-1354.6403149514724 steps:158000
#  [Evaluate] Step_0158000: mean_reward:-1304.1793637426106
#  #790: episode_reward:-1423.3475631725275 steps:158200
#  #791: episode_reward:-1300.8664562186216 steps:158400
#  #792: episode_reward:-1585.0124644581754 steps:158600
# ...
#  #2568: episode_reward:-1051.199682997951 steps:513800
#  #2569: episode_reward:-1367.5141665048027 steps:514000
#  [Evaluate] Step_0514000: mean_reward:-1357.1777248635376
#  #2570: episode_reward:-1731.0619338747636 steps:514200
#  #2571: episode_reward:-958.5639262439355 steps:514400
#  #2572: episode_reward:-1697.2715046746775 steps:514600
#  #2573: episode_reward:-1641.1851218868683 steps:514800
#  #2574: episode_reward:-1676.7683908435151 steps:515000
#  #2575: episode_reward:-1303.993183928553 steps:515200
#  #2576: episode_reward:-1463.0455660671248 steps:515400
#  #2577: episode_reward:-1639.5667285271745 steps:515600
#  #2578: episode_reward:-1395.0219301276825 steps:515800
#  #2579: episode_reward:-1346.8284070814711 steps:516000
#  [Evaluate] Step_0516000: mean_reward:-1368.3057312442363
#  #2580: episode_reward:-1181.4912044220262 steps:516200
#  #2581: episode_reward:-1340.8533362908001 steps:516400
#  #2582: episode_reward:-1385.5644846921518 steps:516600
#  #2583: episode_reward:-1168.1777010661917 steps:516800
#  #2584: episode_reward:-1048.9793522699092 steps:517000
#  #2585: episode_reward:-1349.5599065082363 steps:517200
#  #2586: episode_reward:-1362.1584727309678 steps:517400
#  #2587: episode_reward:-1459.9243002572634 steps:517600
#  #2588: episode_reward:-1342.0504963480435 steps:517800
#  #2589: episode_reward:-1123.481947697447 steps:518000
#  [Evaluate] Step_0518000: mean_reward:-1338.060278731492
#  #2590: episode_reward:-1599.228001351011 steps:518200
#  #2591: episode_reward:-1091.616674763055 steps:518400
#  #2592: episode_reward:-1352.7943434267024 steps:518600
#  #2593: episode_reward:-841.3680490770638 steps:518800
#  #2594: episode_reward:-947.5440696822795 steps:519000
#  #2595: episode_reward:-1368.4869016645557 steps:519200
#  #2596: episode_reward:-1372.5509639109048 steps:519400
#  #2597: episode_reward:-1636.6597748211123 steps:519600
#  #2598: episode_reward:-1357.3568985165846 steps:519800
#  #2599: episode_reward:-1394.2963861444885 steps:520000
#  [Evaluate] Step_0520000: mean_reward:-1249.7491146148368
#  #2600: episode_reward:-969.417611670521 steps:520200
#  #2601: episode_reward:-1348.5850297118948 steps:520400
#  #2602: episode_reward:-1172.511208454048 steps:520600
#  #2603: episode_reward:-1732.3321696236717 steps:520800
#  #2604: episode_reward:-1624.8717586071398 steps:521000
#  #2605: episode_reward:-1617.1466542676612 steps:521200
#  #2606: episode_reward:-1358.7093611941223 steps:521400
#  #2607: episode_reward:-862.0883337223831 steps:521600
#  #2608: episode_reward:-1735.0646303210322 steps:521800
#  #2609: episode_reward:-1344.6498006418935 steps:522000
#  [Evaluate] Step_0522000: mean_reward:-1266.5464457520204
#  #2610: episode_reward:-1739.4606863732417 steps:522200
#  #2611: episode_reward:-1354.1950193090393 steps:522400
#  #2612: episode_reward:-1432.0471506512404 steps:522600
#  #2613: episode_reward:-963.6191632572619 steps:522800
#  #2614: episode_reward:-1353.7901584408512 steps:523000
#  #2615: episode_reward:-1345.5247759786666 steps:523200
#  #2616: episode_reward:-1230.6866454867677 steps:523400
#  #2617: episode_reward:-1138.8310115796203 steps:523600
#  #2618: episode_reward:-1361.918570612988 steps:523800
#  #2619: episode_reward:-1729.8872315761978 steps:524000
#  [Evaluate] Step_0524000: mean_reward:-1334.7479929865456
#  #2620: episode_reward:-1701.099312310955 steps:524200
#  #2621: episode_reward:-1362.5587311625236 steps:524400
#  #2622: episode_reward:-1344.132792705296 steps:524600
#  #2623: episode_reward:-1161.2173021667818 steps:524800
#  #2624: episode_reward:-1651.3791663017364 steps:525000
#  #2625: episode_reward:-1323.1911577310616 steps:525200
#  #2626: episode_reward:-948.2930875732906 steps:525400
#  #2627: episode_reward:-1318.7068392840363 steps:525600
#  #2628: episode_reward:-1162.6559438243162 steps:525800
#  #2629: episode_reward:-1350.8618370481136 steps:526000
#  [Evaluate] Step_0526000: mean_reward:-1265.6019860998965
#  #2630: episode_reward:-1270.5819580797995 steps:526200
#  #2631: episode_reward:-1058.3890638247588 steps:526400
#  #2632: episode_reward:-1327.1089701522496 steps:526600
#  #2633: episode_reward:-1019.4649472098364 steps:526800
#  #2634: episode_reward:-1343.069221455083 steps:527000
#  #2635: episode_reward:-1178.9812249060974 steps:527200
#  #2636: episode_reward:-1290.2878264491603 steps:527400
#  #2637: episode_reward:-1429.4241463480746 steps:527600
#  #2638: episode_reward:-1179.3048809777843 steps:527800
#  #2639: episode_reward:-1463.7764021568655 steps:528000
#  [Evaluate] Step_0528000: mean_reward:-1387.6055377416178
#  #2640: episode_reward:-1641.4598388404959 steps:528200
#  #2641: episode_reward:-1707.3267824901125 steps:528400
#  #2642: episode_reward:-1175.3327007939492 steps:528600
#  #2643: episode_reward:-1227.128930826991 steps:528800
#  #2644: episode_reward:-1360.9382464661383 steps:529000
#  #2645: episode_reward:-1156.8993618804857 steps:529200
#  #2646: episode_reward:-1373.0593307896772 steps:529400
#  #2647: episode_reward:-1490.5854221471752 steps:529600
#  #2648: episode_reward:-1374.0966255563446 steps:529800
#  #2649: episode_reward:-1698.6369404733794 steps:530000
#  [Evaluate] Step_0530000: mean_reward:-1410.8606729340972
#  #2650: episode_reward:-1355.777022084729 steps:530200
#  #2651: episode_reward:-1697.968146434196 steps:530400
#  #2652: episode_reward:-1735.2568760635213 steps:530600
#  #2653: episode_reward:-1352.6559808842455 steps:530800
#  #2654: episode_reward:-1346.929809730423 steps:531000
#  #2655: episode_reward:-1516.558426634218 steps:531200
#  #2656: episode_reward:-1360.7472857227806 steps:531400
#  #2657: episode_reward:-1351.5370861621245 steps:531600
#  #2658: episode_reward:-1236.8055116953776 steps:531800
#  #2659: episode_reward:-1168.4502241157338 steps:532000
#  [Evaluate] Step_0532000: mean_reward:-1370.4894398415759
#  #2660: episode_reward:-1628.613215206879 steps:532200
#  #2661: episode_reward:-951.6342636283385 steps:532400
#  #2662: episode_reward:-1172.3295481884693 steps:532600
#  #2663: episode_reward:-1357.9026826147267 steps:532800
#  #2664: episode_reward:-1356.512891890714 steps:533000
#  #2665: episode_reward:-1345.9482562532294 steps:533200
#  #2666: episode_reward:-1732.7190952804158 steps:533400
#  #2667: episode_reward:-1561.185591428829 steps:533600
#  #2668: episode_reward:-1512.966256814314 steps:533800
#  #2669: episode_reward:-1371.873788487526 steps:534000
#  [Evaluate] Step_0534000: mean_reward:-1379.51628557982
#  #2670: episode_reward:-1353.1678638433061 steps:534200
#  #2671: episode_reward:-1171.1134569042983 steps:534400
#  #2672: episode_reward:-1493.6746301686244 steps:534600
#  #2673: episode_reward:-1178.275266706887 steps:534800
#  #2674: episode_reward:-1594.5274907406397 steps:535000
#  #2675: episode_reward:-1317.1456881987554 steps:535200
#  #2676: episode_reward:-1647.4658275621157 steps:535400
#  #2677: episode_reward:-717.1765136598174 steps:535600
#  #2678: episode_reward:-1355.5573730381502 steps:535800
#  #2679: episode_reward:-1377.4824194236605 steps:536000
#  [Evaluate] Step_0536000: mean_reward:-1319.7595029663496
#  #2680: episode_reward:-1451.108826987541 steps:536200
#  #2681: episode_reward:-1494.0603448110783 steps:536400
#  #2682: episode_reward:-1377.4780401533137 steps:536600
#  #2683: episode_reward:-1058.2599461720918 steps:536800
#  #2684: episode_reward:-1192.738456170207 steps:537000
#  #2685: episode_reward:-1350.9651903759718 steps:537200
#  #2686: episode_reward:-966.6839930845388 steps:537400
#  #2687: episode_reward:-1436.037077289374 steps:537600
#  #2688: episode_reward:-1735.430880112677 steps:537800
#  #2689: episode_reward:-1289.0538739331805 steps:538000
#  [Evaluate] Step_0538000: mean_reward:-1391.0971553180134
#  #2690: episode_reward:-1695.9672680558415 steps:538200
#  #2691: episode_reward:-1288.8245814046127 steps:538400
#  #2692: episode_reward:-1355.6318959253806 steps:538600
#  #2693: episode_reward:-1373.676047932055 steps:538800
#  #2694: episode_reward:-1373.6552149811635 steps:539000
#  #2695: episode_reward:-1365.383657009739 steps:539200
#  #2696: episode_reward:-1347.1972653377459 steps:539400
#  #2697: episode_reward:-869.8791495203897 steps:539600
#  #2698: episode_reward:-1729.5562383988313 steps:539800
#  #2699: episode_reward:-1305.0216076746292 steps:540000
#  [Evaluate] Step_0540000: mean_reward:-1427.35114611406
#  #2700: episode_reward:-952.4182776324478 steps:540200
#  #2701: episode_reward:-1061.188123351787 steps:540400
#  #2702: episode_reward:-1333.1258028538934 steps:540600
#  #2703: episode_reward:-1319.0512970514762 steps:540800
#  #2704: episode_reward:-718.9233052214818 steps:541000
#  #2705: episode_reward:-1357.4931064779946 steps:541200
#  #2706: episode_reward:-1303.0084172198456 steps:541400
#  #2707: episode_reward:-1381.939214584325 steps:541600
#  #2708: episode_reward:-1370.2991782848453 steps:541800
#  #2709: episode_reward:-1278.847923923986 steps:542000
#  [Evaluate] Step_0542000: mean_reward:-1422.5511938728573
#  #2710: episode_reward:-1166.5027463429906 steps:542200
#  #2711: episode_reward:-829.5966789659029 steps:542400
#  #2712: episode_reward:-1059.6989030786162 steps:542600
#  #2713: episode_reward:-1506.9606061622412 steps:542800
#  #2714: episode_reward:-1477.251939816429 steps:543000
#  #2715: episode_reward:-1338.214099074016 steps:543200
#  #2716: episode_reward:-962.5534355660388 steps:543400
#  #2717: episode_reward:-1377.9095435230706 steps:543600
#  #2718: episode_reward:-1433.5203008965163 steps:543800
#  #2719: episode_reward:-1372.0154757302294 steps:544000
#  [Evaluate] Step_0544000: mean_reward:-1399.9122368950548
#  #2720: episode_reward:-1248.8872838647542 steps:544200
#  #2721: episode_reward:-1707.5511652237117 steps:544400
#  #2722: episode_reward:-1371.1001297262305 steps:544600
#  #2723: episode_reward:-1479.1979722277008 steps:544800
#  #2724: episode_reward:-1306.2893915048517 steps:545000
#  #2725: episode_reward:-1347.7827779193778 steps:545200
#  #2726: episode_reward:-1357.8613972600474 steps:545400
#  #2727: episode_reward:-1158.55753992081 steps:545600
#  #2728: episode_reward:-1062.9786785529357 steps:545800
#  #2729: episode_reward:-1062.6660082079427 steps:546000
#  [Evaluate] Step_0546000: mean_reward:-1379.5886843666626
#  #2730: episode_reward:-1300.0952875207486 steps:546200
#  #2731: episode_reward:-1353.6983529299375 steps:546400
#  #2732: episode_reward:-1561.3775659786945 steps:546600
#  #2733: episode_reward:-1480.7427189839273 steps:546800
#  #2734: episode_reward:-1420.0501175145862 steps:547000
#  #2735: episode_reward:-1166.284850863617 steps:547200
#  #2736: episode_reward:-1367.2558901732393 steps:547400
#  #2737: episode_reward:-1135.6732876666956 steps:547600
#  #2738: episode_reward:-1359.8745296757638 steps:547800
#  #2739: episode_reward:-1729.007172711567 steps:548000
#  [Evaluate] Step_0548000: mean_reward:-1369.745370043493
#  #2740: episode_reward:-1735.136854590046 steps:548200
#  #2741: episode_reward:-1338.1069877162502 steps:548400
#  #2742: episode_reward:-984.7262608736473 steps:548600
#  #2743: episode_reward:-1364.4739366667923 steps:548800
#  #2744: episode_reward:-1591.582809885706 steps:549000
#  #2745: episode_reward:-1317.4929431928044 steps:549200
#  #2746: episode_reward:-1521.414649283336 steps:549400
#  #2747: episode_reward:-1561.623159651295 steps:549600
#  #2748: episode_reward:-718.1641416575449 steps:549800
#  #2749: episode_reward:-718.2035503448813 steps:550000
#  [Evaluate] Step_0550000: mean_reward:-1349.2457799154774
#  #2750: episode_reward:-1545.7867535747348 steps:550200
#  #2751: episode_reward:-1178.1355332444068 steps:550400
#  #2752: episode_reward:-1587.5221322456928 steps:550600
#  #2753: episode_reward:-1471.235504113802 steps:550800
#  #2754: episode_reward:-1354.5374015691891 steps:551000
#  #2755: episode_reward:-1084.5190297596232 steps:551200
#  #2756: episode_reward:-1552.2746638670915 steps:551400
#  #2757: episode_reward:-1053.8603261361459 steps:551600
#  #2758: episode_reward:-1663.4299393184613 steps:551800
#  #2759: episode_reward:-1468.9833118822562 steps:552000
#  [Evaluate] Step_0552000: mean_reward:-1342.7550660709358
#  #2760: episode_reward:-1162.6268365692404 steps:552200
#  #2761: episode_reward:-1339.0320529679157 steps:552400
#  #2762: episode_reward:-1067.3374746677448 steps:552600
#  #2763: episode_reward:-1589.4836629675028 steps:552800
#  #2764: episode_reward:-1390.4785108102403 steps:553000
#  #2765: episode_reward:-1492.2313580736304 steps:553200
#  #2766: episode_reward:-1612.5091362179444 steps:553400
#  #2767: episode_reward:-1627.7616166262567 steps:553600
#  #2768: episode_reward:-1359.2117450516578 steps:553800
#  #2769: episode_reward:-1394.680139745757 steps:554000
#  [Evaluate] Step_0554000: mean_reward:-1330.705242051497
#  #2770: episode_reward:-1344.7415203802937 steps:554200
#  #2771: episode_reward:-1700.5010566507317 steps:554400
#  #2772: episode_reward:-1392.8083397655735 steps:554600
#  #2773: episode_reward:-1504.7005499534464 steps:554800
#  #2774: episode_reward:-1362.4584693232223 steps:555000
#  #2775: episode_reward:-1619.0333745014889 steps:555200
#  #2776: episode_reward:-1358.2054717097344 steps:555400
#  #2777: episode_reward:-1367.890748735231 steps:555600
#  #2778: episode_reward:-1692.7045178665853 steps:555800
#  #2779: episode_reward:-1450.0177543394695 steps:556000
#  [Evaluate] Step_0556000: mean_reward:-1211.857756711488
#  #2780: episode_reward:-1517.328608825451 steps:556200
#  #2781: episode_reward:-1719.3944176825532 steps:556400
#  #2782: episode_reward:-1353.782444215315 steps:556600
#  #2783: episode_reward:-1735.6016196579385 steps:556800
#  #2784: episode_reward:-1731.3103562068277 steps:557000
#  #2785: episode_reward:-940.1447638716977 steps:557200
#  #2786: episode_reward:-822.261346436255 steps:557400
#  #2787: episode_reward:-1603.4278383670205 steps:557600
#  #2788: episode_reward:-1514.1474786478793 steps:557800
#  #2789: episode_reward:-1296.7828659007005 steps:558000
#  [Evaluate] Step_0558000: mean_reward:-1397.4682422345659
#  #2790: episode_reward:-1431.3035834748935 steps:558200
#  #2791: episode_reward:-1362.0609922889516 steps:558400
#  #2792: episode_reward:-1363.9699341128503 steps:558600
#  #2793: episode_reward:-1498.3854368663585 steps:558800
#  #2794: episode_reward:-1167.7812559742624 steps:559000
#  #2795: episode_reward:-835.8797820640108 steps:559200
#  #2796: episode_reward:-949.621539802159 steps:559400
#  #2797: episode_reward:-1733.0355302710202 steps:559600
#  #2798: episode_reward:-1163.9523137922945 steps:559800
#  #2799: episode_reward:-1726.223184184962 steps:560000
#  [Evaluate] Step_0560000: mean_reward:-1360.5338910041166
#  #2800: episode_reward:-1309.1006155741668 steps:560200
#  #2801: episode_reward:-1372.9030992355938 steps:560400
#  #2802: episode_reward:-1144.1692946393243 steps:560600
#  #2803: episode_reward:-1360.8146467062336 steps:560800
#  #2804: episode_reward:-1205.094486936494 steps:561000
#  #2805: episode_reward:-1197.3387018818034 steps:561200
#  #2806: episode_reward:-1634.2495555906457 steps:561400
#  #2807: episode_reward:-1372.9677099780072 steps:561600
#  #2808: episode_reward:-1350.2364125053089 steps:561800
#  #2809: episode_reward:-1328.894837823957 steps:562000
#  [Evaluate] Step_0562000: mean_reward:-1350.5995786633
#  #2810: episode_reward:-1522.8177302018503 steps:562200
#  #2811: episode_reward:-1738.9883668562354 steps:562400
#  #2812: episode_reward:-1674.1471580389864 steps:562600
#  #2813: episode_reward:-1376.5370361323028 steps:562800
#  #2814: episode_reward:-1228.0290577631656 steps:563000
#  #2815: episode_reward:-1175.2976978790937 steps:563200
#  #2816: episode_reward:-1386.3573986474432 steps:563400
#  #2817: episode_reward:-1340.8465665159667 steps:563600
#  #2818: episode_reward:-1157.2669550791456 steps:563800
#  #2819: episode_reward:-1357.39757335219 steps:564000
#  [Evaluate] Step_0564000: mean_reward:-1237.3100320449198
#  #2820: episode_reward:-883.9774032354687 steps:564200
#  #2821: episode_reward:-1337.5615743084848 steps:564400
#  #2822: episode_reward:-1716.7184865835015 steps:564600
#  #2823: episode_reward:-944.1402851603935 steps:564800
#  #2824: episode_reward:-1731.627871497765 steps:565000
#  #2825: episode_reward:-1036.4272241670435 steps:565200
#  #2826: episode_reward:-1052.447719549623 steps:565400
#  #2827: episode_reward:-1676.3688154133617 steps:565600

# %% [markdown]
# ## Testing

# %%
def test( num_episodes, model_path, visualize=True, debug=False):
        if agent.load_weights(model_path) == False:
            prRed("model path not found")
            return

        agent.is_training = False
        agent.eval()
        policy = lambda x: agent.select_action(x, noise_enable=False, decay_epsilon=False)

        for i in range(num_episodes):
            validate_reward = evaluate(env, policy, debug=debug, visualize=visualize, save=False)
            if debug: prYellow('[Evaluate] #{}: mean_reward:{}'.format(i, validate_reward))

# %%
test(args.validate_episodes, args.checkpoint, visualize=True, debug=args.debug)

# %% [markdown]
# ##Tensorboard

# %%
# %load_ext tensorboard

# %%
# %tensorboard --logdir runs
